# %%
# # Day 1 - Pandas Basics 🚀

# Today I learned:
# - What is Pandas
# - Series and DataFrame
# - Basic operations like head(), info(), describe()
# - Column selection and modification

# %%
import pandas as pd

data = [10, 20, 30, 40]
s = pd.Series(data)

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([100, 200, 300], index=['A', 'B', 'C'])
s
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data = {
    'Name': ['Jay', 'Raj', 'Meet'],
    'Age': [20, 21, 19]
}

df = pd.DataFrame(data)
df
# Out:
#    Name  Age
# 0   Jay   20
# 1   Raj   21
# 2  Meet   19

# %%
df.head()   # first 5 rows
df.tail()   # last 5 rows
# Out:
#    Name  Age
# 0   Jay   20
# 1   Raj   21
# 2  Meet   19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   20.0
# std     1.0
# min    19.0
# 25%    19.5
# 50%    20.0
# 75%    20.5
# max    21.0

# %%
df['Name']
# Out:
# 0     Jay
# 1     Raj
# 2    Meet
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#    Name  Age
# 0   Jay   20
# 1   Raj   21
# 2  Meet   19

# %%
df['Marks'] = [80, 90, 85]
df
# Out:
#    Name  Age  Marks
# 0   Jay   20     80
# 1   Raj   21     90
# 2  Meet   19     85
