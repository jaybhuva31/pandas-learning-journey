# %%
import pandas as pd

# %%
data = {
    'Name': ['Jay', 'Raj', 'Meet', None],
    'Age': [20, None, 19, 22],
    'Marks': [80, 90, None, 70]
}

df = pd.DataFrame(data)
df
# Out:
#    Name   Age  Marks
# 0   Jay  20.0   80.0
# 1   Raj   NaN   90.0
# 2  Meet  19.0    NaN
# 3  None  22.0   70.0

# %%
df.isnull()
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# Name     1
# Age      1
# Marks    1
# dtype: int64

# %%
df.dropna()
# Out:
#   Name   Age  Marks
# 0  Jay  20.0   80.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.fillna(0)
# Out:
#    Name   Age  Marks
# 0   Jay  20.0   80.0
# 1   Raj   0.0   90.0
# 2  Meet  19.0    0.0
# 3     0  22.0   70.0

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    20.000000
# 1    20.333333
# 2    19.000000
# 3    22.000000
# Name: Age, dtype: float64
